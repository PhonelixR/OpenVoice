# %%
# !git clone https://github.com/PhonelixR/OpenVoice.git
# %cd OpenVoice
# Out:
# Cloning into 'OpenVoice'...
# remote: Enumerating objects: 586, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 586 (delta 78), reused 12 (delta 12), pack-reused 461 (from 2)
# Receiving objects: 100% (586/586), 3.93 MiB | 20.96 MiB/s, done.
# Resolving deltas: 100% (290/290), done.
# /content/OpenVoice

# %%
# !apt-get update
# !apt-get install -y build-essential cmake libpython3-dev ffmpeg
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [83.6 kB]
# ...

# %%
# !pip install torch torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...

# %%
# !pip install librosa soundfile transformers gradio pyworld
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 11.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyworld: filename=pyworld-0.3.5-cp312-cp312-linux_x86_64.whl size=943575 sha256=cbb5593d2c06893d630a007cd22c1c590cefed0e4336e787fab7a108516a97c1
#   Stored in directory: /root/.cache/pip/wheels/be/ac/58/c6a1791ec6d17f3a99b6ccdec92b472f560cb5c564b83dd77e
# Successfully built pyworld
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 56.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 31.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 60.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 22.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 16.6 MB/s eta 0:00:00
# ...

# %%
import os

# URLs de los archivos ZIP (enlaces S3 directos)
urls_zip = {
    'openvoice_v1': 'https://myshell-public-repo-host.s3.amazonaws.com/openvoice/checkpoints_1226.zip',
    'openvoice_v2': 'https://myshell-public-repo-host.s3.amazonaws.com/openvoice/checkpoints_v2_0417.zip'
}

# Descargar y descomprimir cada archivo
for name, url in urls_zip.items():
    zip_filename = os.path.basename(url)
    print(f"Downloading {zip_filename}...")
    # !wget -q $url

    print(f"Decompressing {zip_filename}...")
    # Crear un directorio para descomprimir si es necesario
    extract_dir = os.path.splitext(zip_filename)[0]
    os.makedirs(extract_dir, exist_ok=True)
    # !unzip -q $zip_filename -d $extract_dir
    print(f"Successfully extracted {zip_filename} to {extract_dir}")

print("Download and decompression complete.")
# Out:
# ...
# Decompressing checkpoints_1226.zip...
# Successfully extracted checkpoints_1226.zip to checkpoints_1226
# ...
# Decompressing checkpoints_v2_0417.zip...
# Successfully extracted checkpoints_v2_0417.zip to checkpoints_v2_0417
# Download and decompression complete.

# %%
import os

# Ensure we are in the OpenVoice directory
# This should already be the case from previous steps, but good practice to verify
current_dir = os.getcwd()
if not current_dir.endswith('OpenVoice'):
    os.chdir('OpenVoice')
    print(f"Changed directory to: {os.getcwd()}")

print("Restructuring checkpoint directories...")

# 1. Create the main 'checkpoints' directory if it doesn't exist
os.makedirs('checkpoints/base_speakers', exist_ok=True)
os.makedirs('checkpoints/converter', exist_ok=True)
os.makedirs('checkpoints_v2/base_speakers', exist_ok=True)
os.makedirs('checkpoints_v2/converter', exist_ok=True)

# 2. Copy contents from openvoice_v1 (checkpoints_1226) into the new structure
# Note: cp -r will merge directories if they already exist, copying contents
# !cp -r checkpoints_1226/checkpoints/base_speakers/* checkpoints/base_speakers/
# !cp -r checkpoints_1226/checkpoints/converter/* checkpoints/converter/

# 3. Copy contents from openvoice_v2 (checkpoints_v2_0417) into the new structure
# !cp -r checkpoints_v2_0417/checkpoints_v2/base_speakers/* checkpoints_v2/base_speakers/
# !cp -r checkpoints_v2_0417/checkpoints_v2/converter/* checkpoints_v2/converter/

# 4. Clean up the original extracted directories
# !rm -rf checkpoints_1226
# !rm -rf checkpoints_v2_0417

print("Checkpoint directory restructuring complete.")
print("Verifying new structure:")
# !ls -R checkpoints
# Out:
# Restructuring checkpoint directories...
# Checkpoint directory restructuring complete.
# Verifying new structure:
# checkpoints:
# base_speakers  converter
#
# checkpoints/base_speakers:
# EN  ZH
#
# checkpoints/base_speakers/EN:
# checkpoint.pth	config.json  en_default_se.pth	en_style_se.pth
#
# checkpoints/base_speakers/ZH:
# checkpoint.pth	config.json  zh_default_se.pth
#
# checkpoints/converter:
# checkpoint.pth	config.json

# %%
mods = [
  "librosa","av","faster_whisper","pydub","wavmark","numpy",
  "eng_to_ipa","inflect","unidecode","whisper_timestamped",
  "openai","dotenv","pypinyin","cn2an","jieba","gradio","langid","soundfile","soxr"
]
missing = []
for m in mods:
    try:
        __import__(m.replace("-", "_"))
    except Exception as e:
        missing.append((m, str(e)))
print("Faltan módulos:" if missing else "Todos los módulos requeridos están instalados.")
for m, err in missing:
    print(f" - {m}: {err}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
# ...

# %%
# !jupyter nbconvert --to python demo_part1.ipynb
# Out:
# [NbConvertApp] Converting notebook demo_part1.ipynb to python
# [NbConvertApp] Writing 4382 bytes to demo_part1.py

# %%
# !python demo_part1.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded checkpoint 'checkpoints/base_speakers/EN/checkpoint.pth'
# missing/unexpected keys: [] []
# Loaded checkpoint 'checkpoints/converter/checkpoint.pth'
# missing/unexpected keys: [] []
# OpenVoice version: v1
#  > Text splitted to sentences.
# This audio is generated by OpenVoice.
#  > ===========================
# ðɪs ˈɑdiˌoʊ ɪz ˈdʒɛnəɹˌeɪtɪd baɪ ˈoʊpən vɔɪs.
#  length:45
#  length:45
#  > Text splitted to sentences.
# This audio is generated by OpenVoice.
#  > ===========================
# ðɪs ˈɑdiˌoʊ ɪz ˈdʒɛnəɹˌeɪtɪd baɪ ˈoʊpən vɔɪs.
#  length:45
#  length:45
# ...

# %%
# !jupyter nbconvert --to python demo_part2.ipynb
# Out:
# [NbConvertApp] Converting notebook demo_part2.ipynb to python
# [NbConvertApp] Writing 3927 bytes to demo_part2.py

# %%
# !python demo_part2.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded checkpoint 'checkpoints/converter/checkpoint.pth'
# missing/unexpected keys: [] []
# Traceback (most recent call last):
#   File "/content/OpenVoice/demo_part2.py", line 42, in <module>
#     client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/openai/_client.py", line 137, in __init__
#     raise OpenAIError(
# openai.OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
# !jupyter nbconvert --to python demo_part3.ipynb
# Out:
# [NbConvertApp] Converting notebook demo_part3.ipynb to python
# [NbConvertApp] Writing 3062 bytes to demo_part3.py

# %%
# !python demo_part3.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded checkpoint 'checkpoints_v2/converter/checkpoint.pth'
# missing/unexpected keys: [] []
# OpenVoice version: v2
# [(0.0, 58.8188125)]
# after vad: dur = 58.81798185941043
# Traceback (most recent call last):
#   File "/content/OpenVoice/demo_part3.py", line 49, in <module>
#     from melo.api import TTS
# ModuleNotFoundError: No module named 'melo'

# %%
# !find /content/OpenVoice -type f -name "*.py" | head -30
# Out:
# /content/OpenVoice/openvoice/modules.py
# /content/OpenVoice/openvoice/transforms.py
# /content/OpenVoice/openvoice/text/mandarin.py
# /content/OpenVoice/openvoice/text/__init__.py
# /content/OpenVoice/openvoice/text/symbols.py
# /content/OpenVoice/openvoice/text/cleaners.py
# /content/OpenVoice/openvoice/text/english.py
# /content/OpenVoice/openvoice/mel_processing.py
# /content/OpenVoice/openvoice/commons.py
# /content/OpenVoice/openvoice/models.py
# /content/OpenVoice/openvoice/__init__.py
# /content/OpenVoice/openvoice/utils.py
# /content/OpenVoice/openvoice/api.py
# /content/OpenVoice/openvoice/openvoice_app.py
# /content/OpenVoice/openvoice/attentions.py
# /content/OpenVoice/openvoice/se_extractor.py
# /content/OpenVoice/setup.py
# /content/OpenVoice/demo_part2.py
# /content/OpenVoice/demo_part3.py
# /content/OpenVoice/demo_part1.py

# %%
# !ls -la
# Out:
# total 530096
# drwxr-xr-x 11 root root      4096 Dec  7 15:26 .
# drwxr-xr-x  1 root root      4096 Dec  7 15:22 ..
# drwxr-xr-x  4 root root      4096 Dec  7 15:24 checkpoints
# -rw-r--r--  1 root root 420616031 Jul  5  2024 checkpoints_1226.zip
# drwxr-xr-x  4 root root      4096 Dec  7 15:24 checkpoints_v2
# -rw-r--r--  1 root root 122086901 Jul  5  2024 checkpoints_v2_0417.zip
# -rw-r--r--  1 root root      7365 Dec  7 15:22 demo_part1.ipynb
# -rw-r--r--  1 root root      4416 Dec  7 15:24 demo_part1.py
# -rw-r--r--  1 root root      6835 Dec  7 15:22 demo_part2.ipynb
# -rw-r--r--  1 root root      4392 Dec  7 15:26 demo_part2.py
# -rw-r--r--  1 root root      4869 Dec  7 15:22 demo_part3.ipynb
# -rw-r--r--  1 root root      3194 Dec  7 15:26 demo_part3.py
# drwxr-xr-x  2 root root      4096 Dec  7 15:22 docs
# drwxr-xr-x  8 root root      4096 Dec  7 15:22 .git
# -rw-r--r--  1 root root       134 Dec  7 15:22 .gitignore
# -rw-r--r--  1 root root      1057 Dec  7 15:22 LICENSE
# ...

# %%
# !tree /content/OpenVoice -L 3 2>/dev/null || find /content/OpenVoice -type d | head -30
# Out:
# /content/OpenVoice
# /content/OpenVoice/processed
# /content/OpenVoice/processed/example_reference_v1_Cz+Mo6TtWn_^ElNh_^
# /content/OpenVoice/processed/example_reference_v1_Cz+Mo6TtWn_^ElNh_^/wavs
# /content/OpenVoice/processed/example_reference_v2_Cz+Mo6TtWn_^ElNh_^
# /content/OpenVoice/processed/example_reference_v2_Cz+Mo6TtWn_^ElNh_^/wavs
# /content/OpenVoice/openvoice
# /content/OpenVoice/openvoice/text
# /content/OpenVoice/openvoice/text/__pycache__
# /content/OpenVoice/openvoice/__pycache__
# /content/OpenVoice/checkpoints_v2
# /content/OpenVoice/checkpoints_v2/converter
# /content/OpenVoice/checkpoints_v2/base_speakers
# /content/OpenVoice/checkpoints_v2/base_speakers/ses
# /content/OpenVoice/checkpoints
# /content/OpenVoice/checkpoints/converter
# /content/OpenVoice/checkpoints/base_speakers
# /content/OpenVoice/checkpoints/base_speakers/EN
# /content/OpenVoice/checkpoints/base_speakers/ZH
# /content/OpenVoice/outputs
# /content/OpenVoice/outputs_v2
# ...

# %%
# !pip show gradio
# Out:
# Name: gradio
# Version: 5.50.0
# Summary: Python library for easily interacting with trained machine learning models
# Home-page: https://github.com/gradio-app/gradio
# Author:
# Author-email: Abubakar Abid <gradio-team@huggingface.co>, Ali Abid <gradio-team@huggingface.co>, Ali Abdalla <gradio-team@huggingface.co>, Dawood Khan <gradio-team@huggingface.co>, Ahsen Khaliq <gradio-team@huggingface.co>, Pete Allen <gradio-team@huggingface.co>, Ömer Faruk Özdemir <gradio-team@huggingface.co>, Freddy A Boulton <gradio-team@huggingface.co>, Hannah Blair <gradio-team@huggingface.co>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: aiofiles, anyio, brotli, fastapi, ffmpy, gradio-client, groovy, httpx, huggingface-hub, jinja2, markupsafe, numpy, orjson, packaging, pandas, pillow, pydantic, pydub, python-multipart, pyyaml, ruff, safehttpx, semantic-version, starlette, tomlkit, typer, typing-extensions, uvicorn
# Required-by:

# %%
# Desde el directorio raíz de OpenVoice
# %cd /content/OpenVoice

# Ejecutar como módulo Python
# !python -m openvoice.openvoice_app --share
# Out:
# /content/OpenVoice
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded checkpoint 'checkpoints/base_speakers/EN/checkpoint.pth'
# missing/unexpected keys: [] []
# Loaded checkpoint 'checkpoints/base_speakers/ZH/checkpoint.pth'
# missing/unexpected keys: [] []
# Loaded checkpoint 'checkpoints/converter/checkpoint.pth'
# missing/unexpected keys: [] []
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://9e441e0c9dc0d87810.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# WARNING:  Invalid HTTP request received.
# Detected language:en
# OpenVoice version: v1
# ...

# %%
# Ejecuta esto en una celda de Colab para ver la estructura COMPLETA

print("=== ESTRUCTURA COMPLETA DE CHECKPOINTS V1 ===")
# !find /content/OpenVoice/checkpoints -type f | sort

print("\n\n=== ESTRUCTURA COMPLETA DE CHECKPOINTS V2 ===")
# !find /content/OpenVoice/checkpoints_v2 -type f | sort

print("\n\n=== LISTADO POR DIRECTORIOS ===")
print("checkpoints/")
# !ls -la /content/OpenVoice/checkpoints/
print("\ncheckpoints_v2/")
# !ls -la /content/OpenVoice/checkpoints_v2/

# Mostrar también los subdirectorios
print("\n=== SUBDIRECTORIOS V1 ===")
# !find /content/OpenVoice/checkpoints -type d | sort

print("\n=== SUBDIRECTORIOS V2 ===")
# !find /content/OpenVoice/checkpoints_v2 -type d | sort
# Out:
# === ESTRUCTURA COMPLETA DE CHECKPOINTS V1 ===
# /content/OpenVoice/checkpoints/base_speakers/EN/checkpoint.pth
# /content/OpenVoice/checkpoints/base_speakers/EN/config.json
# /content/OpenVoice/checkpoints/base_speakers/EN/en_default_se.pth
# /content/OpenVoice/checkpoints/base_speakers/EN/en_style_se.pth
# /content/OpenVoice/checkpoints/base_speakers/ZH/checkpoint.pth
# /content/OpenVoice/checkpoints/base_speakers/ZH/config.json
# /content/OpenVoice/checkpoints/base_speakers/ZH/zh_default_se.pth
# /content/OpenVoice/checkpoints/converter/checkpoint.pth
# /content/OpenVoice/checkpoints/converter/config.json
#
#
# === ESTRUCTURA COMPLETA DE CHECKPOINTS V2 ===
# /content/OpenVoice/checkpoints_v2/base_speakers/ses/en-au.pth
# /content/OpenVoice/checkpoints_v2/base_speakers/ses/en-br.pth
# /content/OpenVoice/checkpoints_v2/base_speakers/ses/en-default.pth
# /content/OpenVoice/checkpoints_v2/base_speakers/ses/en-india.pth
# ...

# %%
# Ejecutar con captura completa
# %cd /content/OpenVoice
# !python -m openvoice.openvoice_app_v2 --share 2>&1
# Out:
# /content/OpenVoice
# ...
# 🚀 INICIANDO OPENVOICE CON DEBUG ACTIVADO
# ...
# 🔧 Dispositivo: cpu
# 📁 Directorio de salida: outputs
#
# 📦 CARGANDO MODELOS V1...
#   → Cargando modelo base EN...
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Loaded checkpoint 'checkpoints/base_speakers/EN/checkpoint.pth'
# missing/unexpected keys: [] []
#   → Cargando modelo base ZH...
# Loaded checkpoint 'checkpoints/base_speakers/ZH/checkpoint.pth'
# missing/unexpected keys: [] []
#   → Cargando convertidor V1...
# Loaded checkpoint 'checkpoints/converter/checkpoint.pth'
# missing/unexpected keys: [] []
#   → Cargando embeddings V1...
# ✅ MODELOS V1 CARGADOS
#
# 📦 CARGANDO MODELOS V2...
#   → Cargando convertidor V2...
# ...

# %%
# !git clone https://github.com/PhonelixR/MeloTTS.git
# %cd MeloTTS
# Out:
# Cloning into 'MeloTTS'...
# remote: Enumerating objects: 506, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 506 (delta 32), reused 26 (delta 26), pack-reused 469 (from 2)
# Receiving objects: 100% (506/506), 6.09 MiB | 7.43 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# /content/MeloTTS

# %%
# !pip install -r requirements.txt

# %%
import os
os.chdir('/content/MeloTTS')
# !pip install -q -e .
# Out:
#   Preparing metadata (setup.py) ... done

# %%
# !python -m unidic download
# Out:
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# ...
# unidic-3.1.0.zip: 100% 526M/526M [00:21<00:00, 24.8MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir

# %%
# Comando 1: Estructura completa con tree (si está instalado)
# !find /content -type f -name "*.py" | grep -i melo | sort

# Comando 2: Si no hay resultados, busca en todo el sistema
# !find / -type f -name "*.py" 2>/dev/null | grep -i melo | head -50

# Comando 3: Para ver estructura de directorios
# !ls -la /content/ 2>/dev/null || echo "No hay /content"
# !ls -la / 2>/dev/null | grep -i melo

# Comando 4: Si sabes la ruta exacta del proyecto
# !find /content/melotts -type f -name "*.py" 2>/dev/null | sort
# Out:
# /content/MeloTTS/melo/api.py
# /content/MeloTTS/melo/app.py
# /content/MeloTTS/melo/attentions.py
# /content/MeloTTS/melo/commons.py
# /content/MeloTTS/melo/data_utils.py
# /content/MeloTTS/melo/download_utils.py
# /content/MeloTTS/melo/infer.py
# /content/MeloTTS/melo/init_downloads.py
# /content/MeloTTS/melo/__init__.py
# /content/MeloTTS/melo/losses.py
# /content/MeloTTS/melo/main.py
# /content/MeloTTS/melo/mel_processing.py
# /content/MeloTTS/melo/models.py
# /content/MeloTTS/melo/modules.py
# /content/MeloTTS/melo/monotonic_align/core.py
# /content/MeloTTS/melo/monotonic_align/__init__.py
# /content/MeloTTS/melo/preprocess_text.py
# /content/MeloTTS/melo/split_utils.py
# /content/MeloTTS/melo/text/chinese_bert.py
# /content/MeloTTS/melo/text/chinese_mix.py
# /content/MeloTTS/melo/text/chinese.py
# /content/MeloTTS/melo/text/cleaner_multiling.py
# /content/MeloTTS/melo/text/cleaner.py
# /content/MeloTTS/melo/text/english_bert.py
# /content/MeloTTS/melo/text/english.py
# ...

# %%
# Ejecuta esto en Colab para NLTK:
# !python -c "import nltk; nltk.download('averaged_perceptron_tagger')"
# !python -c "import nltk; nltk.download('punkt')"
# !python -c "import nltk; nltk.download('cmudict')"
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.

# %%
import nltk
import ssl

# Create an unverified SSL context to handle download errors in environments like Colab[citation:5]
try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

# Download the required NLTK data
nltk.download('averaged_perceptron_tagger_eng', quiet=True)
# Out:
# True

# %%
# Desde el directorio raíz de MeloTTS
# %cd /content/MeloTTS/melo

# Ejecutar como módulo Python
# !python -m app --share
# Out:
# /content/MeloTTS/melo
# Make sure you've downloaded unidic (python -m unidic download) for this WebUI to work.
# /content/MeloTTS/melo/app.py:62: DeprecationWarning: The 'show_api' parameter in launch() will be removed in Gradio 6.0. You will need to use the 'footer_links' parameter instead. To replicate show_api=False, In Gradio 6.0, use footer_links=['gradio', 'settings'].
#   demo.queue(api_open=False).launch(
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a8ce617abeffeb08e0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#  > Text split to sentences.
# The field of text-to-speech has seen rapid development recently.
#  > ===========================
# ...

# %%
import torch, librosa
print(torch.__version__)
print(librosa.__version__)
# Out:
# 2.9.0+cu126
# 0.11.0

# %%
import torch
import librosa
import numpy as np

print(f"torch: {torch.__version__}")
print(f"librosa: {librosa.__version__}")

# Test 1: Verificar si librosa.util.pad_center existe
try:
    from librosa.util import pad_center
    print("✅ librosa.util.pad_center existe")
except ImportError:
    print("❌ librosa.util.pad_center NO existe")

# Test 2: Verificar torch.stft con return_complex=False
try:
    y = torch.randn(16000)
    spec = torch.stft(y, n_fft=1024, hop_length=256, win_length=1024,
                      window=torch.hann_window(1024), return_complex=False)
    print("✅ torch.stft con return_complex=False funciona")
except Exception as e:
    print(f"❌ torch.stft con return_complex=False falla: {e}")

# Test 3: Verificar torch.stft sin return_complex
try:
    y = torch.randn(16000)
    spec = torch.stft(y, n_fft=1024, hop_length=256, win_length=1024,
                      window=torch.hann_window(1024))
    print(f"✅ torch.stft sin return_complex funciona, tipo: {type(spec)}")
except Exception as e:
    print(f"❌ torch.stft sin return_complex falla: {e}")
# Out:
# torch: 2.9.0+cu126
# librosa: 0.11.0
# ✅ librosa.util.pad_center existe
# ✅ torch.stft con return_complex=False funciona
# ❌ torch.stft sin return_complex falla: stft requires the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release.
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:681: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /pytorch/aten/src/ATen/native/SpectralOps.cpp:875.)
#   return _VF.stft(  # type: ignore[attr-defined]

# %%
# Depuración simple para ver qué está pasando
import sys
sys.path.append('/content/MeloTTS')

from melo.text import english
from melo.text.cleaner import clean_text

# Prueba con texto simple
text = "Hello world"
print("Testing g2p directly...")
phones, tones, word2ph = english.g2p(text)
print(f"Phones: {phones}")
print(f"Tones: {tones}")
print(f"word2ph: {word2ph}")

# Prueba clean_text
print("\nTesting clean_text...")
norm_text, phones2, tones2, word2ph2 = clean_text(text, "EN")
print(f"Norm text: {norm_text}")
print(f"Phones: {phones2}")
print(f"Tones: {tones2}")
print(f"word2ph: {word2ph2}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Testing g2p directly...
# Phones: ['_', 'hh', 'ah', 'l', 'ow', 'w', 'er', 'l', 'd', '_']
# Tones: [0, 0, 1, 0, 2, 0, 2, 0, 0, 0]
# word2ph: [1, 4, 4, 1]
#
# Testing clean_text...
# Norm text: hello world
# Phones: ['_', 'hh', 'ah', 'l', 'ow', 'w', 'er', 'l', 'd', '_']
# Tones: [0, 0, 1, 0, 2, 0, 2, 0, 0, 0]
# word2ph: [1, 4, 4, 1]

# %%
# %cd ..
# %cd test
# !python test_base_model_tts_package.py ES
# Out:
# /content/MeloTTS
# /content/MeloTTS/test
#  > Text split to sentences.
# El resplandor del sol acaricia las olas, pintando el cielo con una paleta deslumbrante.
#  > ===========================
# 100% 1/1 [00:13<00:00, 13.32s/it]
#  > Text split to sentences.
# Las estrellas bailan en la noche, creando un espectáculo celestial que despierta el alma.
#  > ===========================
# 100% 1/1 [00:09<00:00,  9.49s/it]
#  > Text split to sentences.
# Las majestuosas montañas se alzan en silencio, guardianas inmutables del tiempo que pasa.
#  > ===========================
# 100% 1/1 [00:10<00:00, 10.67s/it]
#  > Text split to sentences.
# El amor, como un suave perfume, envuelve nuestros corazones con un calor reconfortante.
#  > ===========================
# 100% 1/1 [00:09<00:00,  9.58s/it]
#  > Text split to sentences.
# El susurro suave del viento atraviesa los campos de lavanda, llevándose consigo el aroma de la Provenza.
#  > ===========================
# ...

# %%
# !python test_base_model_tts_package_from_S3.py ES
# Out:
# Traceback (most recent call last):
#   File "/content/MeloTTS/test/test_base_model_tts_package_from_S3.py", line 1, in <module>
#     from melo.api import TTS
#   File "/content/MeloTTS/melo/api.py", line 4, in <module>
#     import torch
# object address  : 0x7bce89beab00
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr
# ^C
